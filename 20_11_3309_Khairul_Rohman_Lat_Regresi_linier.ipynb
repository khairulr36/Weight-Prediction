# %%
# Impor library yang dibutuhkan
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/MyDrive/SEMESTER_5/Big_Data_Mining/Dataset/StudentPerformancev3 (1).csv')

# %%
print(df.tail())
# Out:
#      id_mhs            nama jenis_kelamin  umur      jurusan  konsentrasi  \
# 145     146  Agustin Herman        Wanita    26  Informatika     Jaringan
# 146     147    Kelly Brewer          Pria    24  Informatika   Multimedia
# 147     148        Roy Clay          Pria    22  Informatika     Jaringan
# 148     149    Clayton Lynn          Pria    19  Informatika  Pemrograman
# 149     150   Johnny Flores          Pria    27  Informatika  Pemrograman
#
#            asal    kos  uang_saku  paket_data  ... jumlah_org score_toefl  \
# 145  Yogyakarta  Tidak     300000       80000  ...          3          60
# 146      Maluku  Tidak    1100000       90000  ...          3          58
# 147      Manado     Ya    1200000      150000  ...          1         118
# 148     Bandung     Ya     800000      170000  ...          2         114
# 149  Yogyakarta  Tidak     400000       50000  ...          2          66
#
# ...

# %%
df.head()
# Out:
#    id_mhs           nama jenis_kelamin  umur      jurusan  konsentrasi  \
# 0       1       Julianto          Pria    20  Informatika  Pemrograman
# 1       2   Siti Muniroh        Wanita    19  Informatika     Jaringan
# 2       3   Achmad Sandi          Pria    22  Informatika   Multimedia
# 3       4    Adam Sautin          Pria    20  Informatika     Jaringan
# 4       5  Ade R. S1rief          Pria    21  Informatika   Multimedia
#
#          asal    kos  uang_saku  paket_data  ... jumlah_org score_toefl  \
# 0  Yogyakarta  Tidak     200000       50000  ...          2         119
# 1     Jakarta     Ya     500000       70000  ...          2         117
# 2  Yogyakarta  Tidak     300000      100000  ...          1          90
# 3  Yogyakarta  Tidak     700000      100000  ...          1          97
# 4    Surabaya     Ya     800000       80000  ...          1         114
#
#   jumlah_lomba keadaan_ortu_divorced  romance  ukuran_sepatu  tinggi_badan  \
# ...

# %%
df.shape
# Out:
# (150, 34)

# %%
df.shape
# Out:
# (150, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_mhs                    150 non-null    int64
#  1   nama                      150 non-null    object
#  2   jenis_kelamin             150 non-null    object
#  3   umur                      150 non-null    int64
#  4   jurusan                   150 non-null    object
#  5   konsentrasi               150 non-null    object
#  6   asal                      150 non-null    object
#  7   kos                       150 non-null    object
#  8   uang_saku                 150 non-null    int64
#  9   paket_data                150 non-null    int64
#  10  kendaraan                 150 non-null    object
#  11  laptop                    150 non-null    object
#  12  tipe_laptop               150 non-null    object
# ...

# %%
df.describe()
# Out:
#            id_mhs        umur     uang_saku     paket_data     ip_sem1  \
# count  150.000000  150.000000  1.500000e+02     150.000000  150.000000
# mean    75.500000   23.440000  7.813333e+05  115633.333333    3.496000
# std     43.445368    2.386989  3.765592e+05   48081.644304    0.340771
# min      1.000000   19.000000  2.000000e+05   40000.000000    3.000000
# 25%     38.250000   21.250000  5.000000e+05   70000.000000    3.200000
# 50%     75.500000   24.000000  8.000000e+05  120000.000000    3.500000
# 75%    112.750000   25.000000  1.100000e+06  150000.000000    3.800000
# max    150.000000   27.000000  1.400000e+06  200000.000000    4.000000
#
#           ip_sem2     ip_sem3     ip_sem4  persentase_presensi  \
# count  150.000000  150.000000  150.000000           150.000000
# mean     3.484667    3.469333    3.525267            63.533333
# std      0.303002    0.320381    0.321452            20.120999
# min      3.000000    3.000000    3.000000            40.000000
# ...

# %%
df.isnull().sum()
# Out:
# id_mhs                      0
# nama                        0
# jenis_kelamin               0
# umur                        0
# jurusan                     0
# konsentrasi                 0
# asal                        0
# kos                         0
# uang_saku                   0
# paket_data                  0
# kendaraan                   0
# laptop                      0
# tipe_laptop                 0
# status_menikah              0
# ip_sem1                     0
# ip_sem2                     0
# ip_sem3                     0
# ip_sem4                     0
# persentase_presensi         0
# kacamata                    0
# gamer                       0
# durasi_sosmed (jam/hari)    0
# jumlah_akun_sosmed          0
# clubbing                    0
# jumlah_org                  0
# score_toefl                 0
# jumlah_lomba                0
# keadaan_ortu_divorced       0
# romance                     0
# ukuran_sepatu               0
# tinggi_badan                0
# ...

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['tinggi_badan'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['tinggi_badan'])
plt.show()

# %%
#Melakukan Exploratory Data Analysis (EDA) untuk lebih mengenal data kita dan menemukan insights dari data.
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['berat_badan'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['berat_badan'])
plt.show()

# %%
plt.scatter(df['tinggi_badan'], df['berat_badan'])
plt.xlabel('tinggi_badan')
plt.ylabel('berat_badan')
plt.title('Scatter Plot tinggi_badan vs berat_badan')
plt.show()

# %%
df.corr()
# Out:
#                             id_mhs      umur  uang_saku  paket_data   ip_sem1  \
# id_mhs                    1.000000  0.156421   0.081925    0.231446 -0.253022
# umur                      0.156421  1.000000   0.020399    0.119772 -0.294441
# uang_saku                 0.081925  0.020399   1.000000    0.038838 -0.137355
# paket_data                0.231446  0.119772   0.038838    1.000000  0.003637
# ip_sem1                  -0.253022 -0.294441  -0.137355    0.003637  1.000000
# ip_sem2                   0.019272 -0.287085   0.021003   -0.027199 -0.045935
# ip_sem3                  -0.012802 -0.306511  -0.042327   -0.068004  0.036367
# ip_sem4                  -0.116372 -0.289060   0.042513   -0.047005  0.045348
# persentase_presensi      -0.112069 -0.819450   0.014255   -0.087830  0.306585
# durasi_sosmed (jam/hari)  0.138427  0.721233  -0.034286    0.108181 -0.322164
# jumlah_akun_sosmed        0.133359  0.736206  -0.019174    0.159386 -0.290928
# ...

# %%
databaru = df[['tinggi_badan', 'berat_badan']]
print(databaru)
# Out:
#      tinggi_badan  berat_badan
# 0             165         62.5
# 1             141         57.9
# 2             151         59.8
# 3             140         57.8
# 4             165         62.5
# ..            ...          ...
# 145           173         64.0
# 146           167         62.9
# 147           176         64.6
# 148           183         66.1
# 149           174         64.5
#
# [150 rows x 2 columns]

# %%
#selain menggunakan data set baru bisa menggunakan perulangan
# x = df.tinggi_badan.values
# x_temp = []
# for row in range(0,len(x)):
#   temp_var = []
#   temp_var.append(temp_var)
# x = x_tempy = df.berat_badan.values

# %%
databaru.corr()
# Out:
#               tinggi_badan  berat_badan
# tinggi_badan      1.000000     0.998192
# berat_badan       0.998192     1.000000

# %%
X = databaru.iloc[:, :-1].values
print(X)
# Out:
# [[165]
#  [141]
#  [151]
#  [140]
#  [165]
#  [154]
#  [157]
#  [175]
#  [141]
#  [151]
#  [181]
#  [158]
#  [182]
#  [185]
#  [146]
#  [145]
#  [169]
#  [153]
#  [143]
#  [175]
#  [152]
#  [177]
#  [141]
#  [147]
#  [183]
#  [168]
#  [182]
#  [170]
#  [159]
#  [159]
#  [183]
#  [184]
#  [156]
#  [143]
#  [175]
#  [140]
#  [167]
#  [158]
#  [168]
#  [175]
#  [152]
#  [175]
#  [183]
#  [140]
#  [160]
#  [172]
#  [156]
#  [154]
#  [180]
#  [181]
#  [172]
#  [176]
#  [148]
#  [173]
#  [178]
#  [140]
#  [148]
#  [181]
#  [167]
#  [161]
#  [145]
#  [150]
#  [172]
#  [157]
#  [175]
#  [142]
#  [167]
#  [184]
#  [147]
#  [177]
#  [148]
#  [152]
#  [142]
#  [162]
#  [144]
#  [156]
#  [154]
#  [154]
#  [151]
#  [178]
#  [178]
#  [161]
#  [170]
#  [166]
#  [150]
#  [177]
#  [140]
#  [153]
#  [175]
#  [172]
#  [180]
#  [182]
#  [143]
#  [177]
#  [140]
#  [176]
#  [177]
#  [178]
#  [140]
#  [161]
#  [169]
#  [171]
#  [147]
#  [140]
#  [183]
#  [140]
#  [180]
#  [177]
#  [147]
#  [182]
#  [145]
# ...

# %%
Y = databaru.iloc[:, 1].values
print(Y)
# Out:
# [62.5 57.9 59.8 57.8 62.5 60.8 61.1 64.5 57.9 60.2 65.5 61.6 66.  66.4
#  58.9 58.7 63.3 60.5 58.2 64.5 60.  65.2 57.8 59.  66.3 63.5 66.  63.5
#  61.6 61.5 65.9 66.  61.1 58.3 64.7 57.8 63.  61.6 63.4 64.5 60.3 64.8
#  65.9 57.7 61.6 64.  61.1 60.4 65.3 65.8 64.1 65.  59.5 64.2 65.  57.7
#  59.2 65.9 63.2 62.  58.9 60.  63.8 61.1 64.7 58.  62.9 66.  59.  64.8
#  59.3 60.4 58.  62.4 58.8 60.8 60.4 60.8 60.1 65.2 65.  61.8 63.6 62.9
#  60.  65.  58.  60.5 64.5 64.1 65.7 66.  58.3 65.2 57.8 64.7 65.2 65.2
#  58.  61.8 63.3 63.9 59.  58.  66.  58.  65.6 64.8 59.4 65.8 58.9 60.3
#  61.6 65.9 64.4 58.3 61.6 60.  60.6 63.5 63.8 62.  63.6 62.1 60.  65.
#  61.6 61.3 64.7 65.5 62.  60.  64.2 61.3 58.  66.5 60.  58.6 60.1 64.6
#  58.4 62.5 64.5 64.4 62.2 64.  62.9 64.6 66.1 64.5]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 0) 
print(X_train.shape)
print(X_train)
# Out:
# (105, 1)
# [[145]
#  [160]
#  [161]
#  [168]
#  [147]
#  [177]
#  [184]
#  [148]
#  [178]
#  [162]
#  [157]
#  [180]
#  [167]
#  [172]
#  [176]
#  [177]
#  [183]
#  [171]
#  [140]
#  [175]
#  [172]
#  [182]
#  [177]
#  [180]
#  [185]
#  [153]
#  [176]
#  [152]
#  [145]
#  [148]
#  [140]
#  [174]
#  [140]
#  [157]
#  [147]
#  [182]
#  [177]
#  [182]
#  [147]
#  [172]
#  [183]
#  [175]
#  [156]
#  [158]
#  [145]
#  [150]
#  [175]
#  [183]
#  [141]
#  [183]
#  [174]
#  [183]
#  [165]
#  [181]
#  [153]
#  [168]
#  [154]
#  [173]
#  [173]
#  [140]
#  [165]
#  [175]
#  [159]
#  [140]
#  [156]
#  [140]
#  [147]
#  [144]
#  [184]
#  [155]
#  [181]
#  [152]
#  [142]
#  [156]
#  [151]
#  [146]
#  [169]
#  [175]
#  [159]
#  [162]
#  [181]
#  [150]
#  [161]
#  [170]
#  [178]
#  [142]
#  [173]
#  [142]
#  [154]
#  [168]
#  [161]
#  [142]
#  [175]
#  [175]
#  [167]
#  [175]
#  [148]
#  [153]
#  [167]
#  [177]
#  [151]
#  [140]
#  [184]
#  [150]
#  [154]]

# %%
# panggil modul LinearRegression untuk menjalankan regresi liear
from sklearn.linear_model import LinearRegression
# membuat objek regresi linear
lin_reg = LinearRegression()
# membangun model (training model dari data set yang sudah kita split)
lin_reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
print(lin_reg.coef_)
print(lin_reg.intercept_)
# Out:
# [0.19104309]
# 31.142734474715013

# %%
Y_prediksi = lin_reg.predict(X_test)

# %%
df = pd.DataFrame({'aktual': Y_test, 'Prediksi': Y_prediksi})
print(df)
# Out:
#     aktual   Prediksi
# 0     64.4  64.384232
# 1     63.8  64.002146
# 2     58.3  58.461896
# 3     64.8  64.957361
# 4     64.5  64.575275
# 5     63.3  63.429016
# 6     60.3  60.181284
# 7     58.0  57.888767
# 8     60.4  60.563370
# 9     60.4  60.181284
# 10    58.0  57.888767
# 11    65.0  64.766318
# 12    62.4  62.091715
# 13    65.0  65.148404
# 14    61.1  61.136499
# 15    61.6  61.327542
# 16    60.1  59.990241
# 17    65.7  65.530490
# 18    64.0  64.002146
# 19    63.3  63.429016
# 20    62.0  61.900672
# 21    62.9  63.046930
# 22    66.3  66.103620
# 23    57.9  58.079810
# 24    61.6  61.518585
# 25    57.8  58.079810
# 26    61.6  61.709629
# 27    65.2  65.148404
# 28    65.2  64.957361
# 29    66.0  65.912576
# 30    58.6  58.461896
# 31    60.0  59.799198
# 32    63.5  63.620059
# 33    61.3  61.136499
# 34    64.2  64.002146
# 35    62.0  61.900672
# 36    58.2  58.461896
# 37    62.9  62.855887
# 38    60.0  59.799198
# 39    58.3  58.461896
# ...

# %%
df.plot(kind='bar',figsize=(12,4))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_prediksi))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_prediksi))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_prediksi)))
# Out:
# Mean Absolute Error: 0.15193343407225024
# Mean Squared Error: 0.02804985762436811
# Root Mean Squared Error: 0.1674809171946706

# %%
plt.scatter(X_train, Y_train)
plt.plot(X_train, lin_reg.predict(X_train), c='red')
plt.xlabel('tinggi_badan')
plt.ylabel('berat_badan')
plt.title('Prediksi berat badan berdasarkan tinggi badan (training set)')
# Out:
# Text(0.5, 1.0, 'Prediksi berat badan berdasarkan tinggi badan (training set)')

# %%
plt.scatter(X_test, Y_test)
plt.plot(X_test, Y_prediksi, c='r')
plt.xlabel('tinggi_badan')
plt.ylabel('berat_badan')
plt.title('Prediksi berat badan berdasarkan tinggi badan (training set)')
# Out:
# Text(0.5, 1.0, 'Prediksi berat badan berdasarkan tinggi badan (training set)')

# %%
print('Berat badan seseorang berdasarkan tinggi 160 cm adalah : ',lin_reg.predict([[160]]))
print('Berat badan seseorang berdasarkan tinggi 151 cm adalah : ',lin_reg.predict([[151]]))
print('Berat badan seseorang berdasarkan tinggi 168 cm adalah : ',lin_reg.predict([[177]]))
# Out:
# Berat badan seseorang berdasarkan tinggi 160 cm adalah :  [61.70962854]
# Berat badan seseorang berdasarkan tinggi 151 cm adalah :  [59.99024075]
# Berat badan seseorang berdasarkan tinggi 168 cm adalah :  [64.95736103]
